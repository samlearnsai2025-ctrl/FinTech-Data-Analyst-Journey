# %%
# import required libraries
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Download stock data for Apple in 2023
data = yf.download('AAPL', start='2023-01-01', end='2023-12-31')
# Out:
# C:\Users\samee\AppData\Local\Temp\ipykernel_18296\3488600744.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download('AAPL', start='2023-01-01', end='2023-12-31')
# [*********************100%***********************]  1 of 1 completed

# %%
# Inspect the first few rows
print(data.head())
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2023-01-03  123.330658  129.079575  122.443173  128.468202  112117500
# 2023-01-04  124.602707  126.870724  123.340509  125.125335   89113600
# 2023-01-05  123.281334  125.993089  123.024955  125.361991   80962700
# 2023-01-06  127.817360  128.478040  123.153145  124.257571   87754700
# 2023-01-09  128.339981  131.554653  128.083602  128.655538   70790800

# %%
# Plot closing price
plt.figure(figsize=(10, 4))
plt.plot(data['Close'], label='AAPL Close')
plt.title('Apple Stock Price in 2023')
plt.xlabel('Date')
plt.ylabel(' Close Price ($) ')
plt.legend()
plt.show()
